# %%
options(warn=-1)
suppressMessages(library(ggplot2))
suppressMessages(library(dplyr))
suppressMessages(require(tidyverse))
suppressMessages(require(Cairo))
suppressMessages(require(showtext))
rm(list = ls())

setwd("~/Documents/CPIC/fund_simulation/code/")

# 模式1
rolling1 <- read.csv("../result/rolling1yrs.csv")
rolling2 <- read.csv("../result/rolling2yrs.csv")
rolling3 <- read.csv("../result/rolling3yrs.csv")
# rolling4 <- read.csv("../result/rolling4yrs.csv")

# %%
rolling3[order(rolling3$mode),]
# Out:
#    year                   account_code mode  return_margin return_margin2
# 1  2006-12-29--2016-01-04 161005.OF    mode1 179641603     198532427
# 3  2007-12-28--2017-01-03 161005.OF    mode1 129549416     157295261
# 5  2008-12-31--2018-01-02 161005.OF    mode1 187420772     193635490
# 7  2009-12-31--2019-01-02 161005.OF    mode1  84422151      91553170
# 9  2010-12-31--2020-01-02 161005.OF    mode1 109235105     133523067
# 11 2011-12-30--2021-01-04 161005.OF    mode1 316751206     316751206
# 2  2006-12-29--2016-01-04 161005.OF    mode2 455918669     516151592
# 4  2007-12-28--2017-01-03 161005.OF    mode2 458291516     524027545
# 6  2008-12-31--2018-01-02 161005.OF    mode2 219252113     255246941
# 8  2009-12-31--2019-01-02 161005.OF    mode2 259512239     359202917
# 10 2010-12-31--2020-01-02 161005.OF    mode2 226250593     356940447
# 12 2011-12-30--2021-01-04 161005.OF    mode2 593672774     593672774
#    return_margin3 E_end       excess_return upper_limit acc_return
# 1  188294210      12455784400 4097759460    252423842    6561629201
# 3   74580177       5745033937 1557498808    194718567    1810379642
# 5  177856985       9333133538 2367442704    268313346    3440107534
# 7   88437141       5792918762 1327970025    309543011   -1959543568
# 9   61749736       6437529253 1092351054    191814892    1564147830
# 11 316751206      16876058672 5059892501    354302232    7333894855
# 2  584656490      17058330627 9255429105    668375492   12106586652
# 4  546167158       7152623392 5526077172    758719278    7053243060
# 6  205273647      12758156656 5023697013    504935292    5788816246
# 8  303778769       7212240468 5260376490    799083669   -3375794394
# 10 282167724      15428464644 2262505926    486315138    3311907680
# 12 598272923      19810237507 7436172237    713930620    7928905224
#    Emean_return ret_exc    ret_exc2   ret_exc3   ret_emean  ret_emean2
# 1   4313711481  0.04383898 0.04844902 0.04595053 0.04164433 0.04602358
# 3   3355372544  0.08317786 0.10099222 0.04788458 0.03860955 0.04687863
# 5   5631169879  0.07916592 0.08179099 0.07512620 0.03328274 0.03438637
# 7   6860849868  0.06357233 0.06894220 0.06659574 0.01230491 0.01334429
# 9   3596867811  0.10000000 0.12223458 0.05652920 0.03036951 0.03712204
# 11  7437076881  0.06260038 0.06260038 0.06260038 0.04259082 0.04259082
# 2   9818833805  0.04925959 0.05576744 0.06316903 0.04643308 0.05256750
# 4   8364525721  0.08293252 0.09482813 0.09883452 0.05478990 0.06264881
# 6   6842454899  0.04364358 0.05080859 0.04086107 0.03204290 0.03730342
# 8  13244506556  0.04933340 0.06828464 0.05774848 0.01959395 0.02712090
# 10  8591727517  0.10000000 0.15776332 0.12471469 0.02633354 0.04154467
# 12 12095206811  0.07983580 0.07983580 0.08045442 0.04908331 0.04908331
#    ret_emean3 year2
# 1  0.04365016 2007
# 3  0.02222709 2008
# 5  0.03158438 2009
# 7  0.01289011 2010
# 9  0.01716764 2011
# 11 0.04259082 2012
# 2  0.05954439 2007
# 4  0.06529565 2008
# 6  0.03000000 2009
# 8  0.02293621 2010
# 10 0.03284179 2011
# 12 0.04946364 2012
