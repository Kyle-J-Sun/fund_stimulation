# %%
options(warn=-1)
suppressMessages(library(ggplot2))
suppressMessages(library(dplyr))
suppressMessages(require(tidyverse))
suppressMessages(require(Cairo))
suppressMessages(require(showtext))
rm(list = ls())

setwd("~/Documents/CPIC/fund_simulation/code/")

# 模式1
rolling1 <- read.csv("../result/rolling1yrs.csv")
rolling2 <- read.csv("../result/rolling2yrs.csv")
rolling3 <- read.csv("../result/rolling3yrs.csv")
# rolling4 <- read.csv("../result/rolling4yrs.csv")

# %%
rolling2[order(rolling2$mode),]
# Out:
#    year                   account_code mode  return_margin return_margin2
# 1  2006-12-29--2013-01-04 161005.OF    mode1  50230258      69121082
# 3  2007-12-28--2014-01-02 161005.OF    mode1  64947259      64435918
# 5  2008-12-31--2015-01-05 161005.OF    mode1  18485675      24700393
# 7  2009-12-31--2016-01-04 161005.OF    mode1  84422151      91553170
# 9  2010-12-31--2017-01-03 161005.OF    mode1  49598794      64206345
# 11 2011-12-30--2018-01-02 161005.OF    mode1  93638900      93638900
# 13 2012-12-31--2019-01-02 161005.OF    mode1  47307756      47307756
# 15 2013-12-31--2020-01-02 161005.OF    mode1  70977914      89590371
# 17 2014-12-31--2021-01-04 161005.OF    mode1 147832343     147832343
# 2  2006-12-29--2013-01-04 161005.OF    mode2 161353655     221586577
# 4  2007-12-28--2014-01-02 161005.OF    mode2 300097260     292540771
# 6  2008-12-31--2015-01-05 161005.OF    mode2  13978466      49973294
# 8  2009-12-31--2016-01-04 161005.OF    mode2 259512239     359202917
# 10 2010-12-31--2017-01-03 161005.OF    mode2  76255015     191365725
# 12 2011-12-30--2018-01-02 161005.OF    mode2 230816570     230816570
# 14 2012-12-31--2019-01-02 161005.OF    mode2 153605169     153605169
# 16 2013-12-31--2020-01-02 161005.OF    mode2  99776656     291147015
# 18 2014-12-31--2021-01-04 161005.OF    mode2 417658548     487224675
#    return_margin3 E_end       excess_return upper_limit acc_return
# 1   58882866       3177861729  502302585    123012498    -219187059
# 3   66761536       2278255907  911477234     94057391     -97837014
# 5    8921889       4439960182 -256403650     99378250    1370450631
# 7   88437141       6384705333 1977751004    103717515    3068944010
# 9   20658751       3024628615  495987945     83908858     953123364
# 11  93638900       5173255149 1209783828    131189925    1906814463
# 13  47307756       4346531594  836042806    201742343   -1470280938
# 15  34263688       4879154464  709779143    121951276    1185504340
# 17 147832343       9219309465 2397949574    147832343    3572888472
# 2  290091475      13218557750 1392930734    373810478    -134905121
